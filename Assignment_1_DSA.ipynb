# %% [markdown]
# #### 1. Read the dataset to python environment.

# %%
#importing packages
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#reading csv file
data=pd.read_excel("C:/Users/rakhi/Downloads/iris_data.xls")

# %%
data
# Out:
#       SL   SW   PL   PW  Classification
# 0    5.1  3.5  1.4  0.2     Iris-setosa
# 1    4.9  3.0  1.4  0.2     Iris-setosa
# 2    4.7  3.2  1.3  0.2     Iris-setosa
# 3    4.6  3.1  1.5  0.2     Iris-setosa
# 4    5.0  3.6  1.4  0.2     Iris-setosa
# ..   ...  ...  ...  ...             ...
# 145  6.7  3.0  5.2  2.3  Iris-virginica
# 146  6.3  2.5  5.0  1.9  Iris-virginica
# 147  6.5  3.0  5.2  2.0  Iris-virginica
# 148  6.2  3.4  5.4  2.3  Iris-virginica
# 149  5.9  3.0  5.1  1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# #### 2. Display the columns in the dataset.

# %%
data.columns
# Out:
# Index(['SL', 'SW', 'PL', 'PW', 'Classification'], dtype='object')

# %% [markdown]
# #### 3. Calculate the mean of each column of the dataset.

# %%
data.mean()
# Out:
# SL    5.843333
# SW    3.054000
# PL    3.758667
# PW    1.198667
# dtype: float64

# %% [markdown]
# #### 4. Check for the null values present in the dataset.

# %%
data.isnull().sum()
# Out:
# SL                0
# SW                0
# PL                0
# PW                0
# Classification    0
# dtype: int64

# %% [markdown]
# There is no null values in the data

# %% [markdown]
# #### 5. Perform meaningful visualizations using the dataset. Bring at least 3 visualizations.

# %%
sns.countplot(data["Classification"])
# Out:
# C:\Users\rakhi\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Classification', ylabel='count'>

# %%
plt.hist(data["SL"],color="purple",bins=20)
plt.title("Histogram of Sepal Length")
plt.xlabel("SL")
plt.ylabel("No. of observations")
# Out:
# Text(0, 0.5, 'No. of observations')

# %%
plt.scatter(data["SL"],data["PL"],s=15)
plt.title("Relationship between sepal length and petal width")
plt.xlabel("SL")
plt.ylabel("PL")
# Out:
# Text(0, 0.5, 'PL')

# %%
sns.scatterplot(data["PL"],data["PW"],hue=data["Classification"]).set(title="Scatterplot of petal length and petal width")
# Out:
# C:\Users\rakhi\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# [Text(0.5, 1.0, 'Scatterplot of petal length and petal width')]

# %%
sns.scatterplot(data["SL"],data["SW"],hue=data["Classification"]).set(title="Scatterplot of sepal length and sepal width")
# Out:
# C:\Users\rakhi\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# [Text(0.5, 1.0, 'Scatterplot of sepal length and sepal width')]

# %%
sns.boxplot(x=data["PW"],y=data["SW"],hue=data["Classification"]).set(title="Boxplot of petal width and sepal width")
# Out:
# [Text(0.5, 1.0, 'Boxplot of petal width and sepal width')]
