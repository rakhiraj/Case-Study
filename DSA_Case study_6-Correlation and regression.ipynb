# %% [markdown]
# ### A textile company regularly spent money on five advertising companies for their ads.

# %%
#importing libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#reading the data
df=pd.read_csv(r"C:\Users\rakhi\Downloads\Add_sales_data_2018.csv")
df
# Out:
#            Date  Add1(in Thousands)  Add2(in Thousands)  Add3(in Thousands)  \
# 0    2018-10-08              208.00              222.25              206.85
# 1    2018-10-05              217.00              218.60              205.90
# 2    2018-10-04              223.50              227.80              216.15
# 3    2018-10-03              230.00              237.50              225.75
# 4    2018-10-01              234.55              234.60              221.05
# ..          ...                 ...                 ...                 ...
# 200  2017-12-14              288.00              288.25              279.20
# 201  2017-12-13              290.00              292.50              282.20
# 202  2017-12-12              298.60              298.60              286.65
# 203  2017-12-11              290.00              299.55              285.90
# 204  2017-12-08              287.55              289.90              285.05
#
# ...

# %%
df.shape
# Out:
# (205, 7)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 7 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Date                  205 non-null    object
#  1   Add1(in Thousands)    205 non-null    float64
#  2   Add2(in Thousands)    205 non-null    float64
#  3   Add3(in Thousands)    205 non-null    float64
#  4   Add4(in Thousands)    205 non-null    float64
#  5   Add5(in Thousands)    205 non-null    float64
#  6   Profit(in Thousands)  205 non-null    float64
# dtypes: float64(6), object(1)
# memory usage: 11.3+ KB

# %%
df.columns
# Out:
# Index(['Date', 'Add1(in Thousands)', 'Add2(in Thousands)',
#        'Add3(in Thousands)', 'Add4(in Thousands)', 'Add5(in Thousands)',
#        'Profit(in Thousands)'],
#       dtype='object')

# %%
#checking missing values
df.isna().sum()
# Out:
# Date                    0
# Add1(in Thousands)      0
# Add2(in Thousands)      0
# Add3(in Thousands)      0
# Add4(in Thousands)      0
# Add5(in Thousands)      0
# Profit(in Thousands)    0
# dtype: int64

# %% [markdown]
# There are no null values

# %%
df.describe()
# Out:
#        Add1(in Thousands)  Add2(in Thousands)  Add3(in Thousands)  \
# count          205.000000          205.000000          205.000000
# mean           267.577561          271.722439          262.990732
# std             26.219588           25.914939           26.126704
# min            208.000000          218.600000          205.900000
# 25%            244.000000          248.500000          240.300000
# 50%            269.700000          274.200000          263.250000
# 75%            284.400000          288.800000          280.900000
# max            327.700000          328.750000          321.650000
#
#        Add4(in Thousands)  Add5(in Thousands)  Profit(in Thousands)
# count          205.000000          205.000000            205.000000
# mean           267.223902          267.152683           5059.630234
# std             26.238832           26.215360            486.910414
# min            210.250000          209.200000           4042.448000
# ...

# %% [markdown]
# ### 1. First of all, check whether there is any relationship between the amount spent for advertising through five different companies and profit generated.

# %%
plt.figure(figsize=(10,5))
sns.scatterplot(df["Add1(in Thousands)"],df["Profit(in Thousands)"]).set(title="Relation bw Add Company 1 and Profit")
# Out:
# C:\Users\rakhi\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# [Text(0.5, 1.0, 'Relation bw Add Company 1 and Profit')]

# %%
plt.figure(figsize=(10,5))
sns.scatterplot(df["Add2(in Thousands)"],df["Profit(in Thousands)"],color="black").set(title="Relation bw Add Company 2 and Profit")
# Out:
# C:\Users\rakhi\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# [Text(0.5, 1.0, 'Relation bw Add Company 2 and Profit')]

# %%
plt.figure(figsize=(10,5))
sns.scatterplot(df["Add3(in Thousands)"],df["Profit(in Thousands)"],color="red").set(title="Relation bw Add Company 3 and Profit")
# Out:
# C:\Users\rakhi\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# [Text(0.5, 1.0, 'Relation bw Add Company 3 and Profit')]

# %%
plt.figure(figsize=(10,5))
sns.scatterplot(df["Add4(in Thousands)"],df["Profit(in Thousands)"],color="green").set(title="Relation bw Add Company 4 and Profit")
# Out:
# C:\Users\rakhi\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# [Text(0.5, 1.0, 'Relation bw Add Company 4 and Profit')]

# %%
plt.figure(figsize=(10,5))
sns.scatterplot(df["Add5(in Thousands)"],df["Profit(in Thousands)"],color="maroon").set(title="Relation bw Add Company 5 and Profit")
# Out:
# C:\Users\rakhi\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# [Text(0.5, 1.0, 'Relation bw Add Company 5 and Profit')]

# %%
plt.figure(figsize=(10,7))
sns.heatmap(df.corr(),annot=True,cmap="cubehelix")
# Out:
# <AxesSubplot:>

# %% [markdown]
# 1. We can see that there ia a strong linear relationship between the companies and the profit.

# %% [markdown]
# 2. The add company 2 has perfect linear relation with profit.

# %% [markdown]
# ### 2. Build a regression model to predict the profit from the given data and comment your findings on it.

# %%
from sklearn.model_selection import train_test_split
from sklearn import linear_model
from sklearn.metrics import mean_squared_error,r2_score

# %%
x= df.drop(["Date","Profit(in Thousands)"], axis=1) #independent features
y= df["Profit(in Thousands)"]

# %%
# Splitting given data into training and test data
x_train, x_test, y_train, y_test= train_test_split(x,y, random_state= 42,test_size= 0.25)

# %%
lr= linear_model.LinearRegression()

# %%
model=lr.fit(x_train, y_train)

# %%
y_pred=lr.predict(x_test)

# %%
mean_squared_error(y_test,y_pred)
# Out:
# 1.0021611267469373e-24

# %%
r2_score(y_test,y_pred)
# Out:
# 1.0

# %% [markdown]
# Since the MSE value is 1.00e-24 and r2_score value is 1,the model is a best fit.

# %% [markdown]
# ### 3. Predict the profit generated by the company, if they wish to spend the following amount for advertisement.

# %% [markdown]
# Add1(in Thousands) 290

# %% [markdown]
# Add2(in Thousands) 312

# %% [markdown]
# Add3(in Thousands) 309

# %% [markdown]
# Add4(in Thousands) 298

# %% [markdown]
# Add5(in Thousands) 320

# %%
y_pred = lr.predict([[290, 312, 309, 298, 320]])

# %%
y_pred
# Out:
# array([5820.06])

# %% [markdown]
# The predicted profit if they spend the given amounts is 5820.96 (in thousands).
